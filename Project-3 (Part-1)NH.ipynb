# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
### 1.Loading the Data ###

# %%
Ds1 = pd.read_csv(r"C:\Users\Anuja Verma\Downloads\housing_data.csv")

# %%
Ds1.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
# 2         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 3         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 4         Lvl    AllPub  ...        0     No    No          No       0    Dec
#
# ...

# %%
### Display Dataset

# %%
Ds1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1460 non-null   int64
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   int64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
### 2.Cleaning the Data ###

# %%
# handling Missing Values

# %%
Ds1.isnull().sum()
# Out:
# Unnamed: 0       0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
Ds1.isnull().sum()[Ds1.isnull().sum()>0]
# Out:
# Alley          1369
# MasVnrType      872
# Electrical        1
# GarageYrBlt      81
# dtype: int64

# %%
# Handling Duplicate Values

# %%
Ds1.duplicated().sum()
# Out:
# 0

# %%
# Remove duplicate rows

# %%
Ds1 = Ds1.drop_duplicates()

# %%
# Address Anomalies

# %%
# Check the cleaned dataset

# %%
Ds1.info()
Ds1.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1460 non-null   int64
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   int64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# Identify Unique Values in All Colimns

# %%
Ds1.nunique()
# Out:
# Unnamed: 0       1460
# MSSubClass         15
# MSZoning            5
# LotFrontage       111
# LotArea          1073
#                  ...
# MoSold             12
# YrSold              5
# SaleType            9
# SaleCondition       6
# SalePrice         663
# Length: 81, dtype: int64

# %%
# Save the cleaned dataset

# %%
Ds1.to_csv('cleaned_housing_data.csv', index=False)

# %%
### 3.Univariate Analysis ###

# %%
# Visualize the Distribution
# Histogram

# %%
plt.figure(figsize=(10, 6))
sns.histplot(Ds1['SalePrice'], bins=30, kde=False, color='blue')
plt.title('Histogram of House Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %%
# Kernel Density Estimate (KDE) Plot

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(Ds1['SalePrice'], color='red', fill=True)
plt.title('KDE Plot of House Prices')
plt.xlabel('Price')
plt.ylabel('Density')
plt.grid()
plt.show()

# %%
#Combined Histogram and KDE Plot

# %%
plt.figure(figsize=(10, 6))
sns.histplot(Ds1['SalePrice'], bins=30, kde=True, color='blue', stat='density', alpha=0.5)
plt.title('Histogram and KDE of House Prices')
plt.xlabel('Price')
plt.ylabel('Density')
plt.grid(axis='y')
plt.show()

# %%
# Summary statistics

# %%
summary_stats = Ds1['SalePrice'].describe()
print(summary_stats)
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
# Identify Outliers

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=Ds1['SalePrice'], color='lightgreen')
plt.title('Box Plot of House Prices')
plt.xlabel('Price')
plt.grid(axis='x')
plt.show()

# %%
#Conclusion
#Through this univariate analysis, you can gain insights into the distribution of house prices, identify any skewness, and detect outliers. 
#The combination of histograms, KDE plots, and box plots provides a comprehensive view of the variable's characteristics. 
#Adjust the parameters and visualizations as needed based on your specific dataset and analysis goals.

# %%
### 4.Multivariate Analysis ###

# %%
#Data Preprocessing

# %%
# Check for missing values
print(Ds1.isnull().sum())

# Fill or drop missing values as necessary
Ds1.fillna(method='ffill', inplace=True)  # Example: forward fill

# Convert categorical variables to numerical if necessary
Ds1 = pd.get_dummies(Ds1, drop_first=True)  # One-hot encoding
# Out:
# Unnamed: 0       0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64
# C:\Users\Anuja Verma\AppData\Local\Temp\ipykernel_24860\3093315835.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Ds1.fillna(method='ffill', inplace=True)  # Example: forward fill

# %%
# Correlation Matrix

# %%
# Calculate the correlation matrix
correlation_matrix = Ds1.corr()

# Set up the matplotlib fgure
plt.figure(figsize=(12, 10))

# Draw the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})

# Title and show the plot
plt.title('Correlation Matrix of House Prices Dataset')
plt.show()

sns.heatmap(Ds1.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
# Correlation heatmap
corr_matrix = Ds1[['SalePrice', 'BedroomAbvGr', 'FullBath', 'BsmtUnfSF', 'LotArea', 'MSSubClass']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Feature Correlation with Price')
plt.show()

# %%
#Pairplot (Scatterplot Matrix)

# %%
# Select a subset of features for the pairplot
features = ['OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'SalePrice']  # Example features
sns.pairplot(Ds1[features], diag_kind='kde')

# Show the plot
plt.suptitle('Pairplot of Selected Features', y=1.02)
plt.show()

# %%
# Scatter Plots

# %%
# Scatter plot for GrLivArea vs SalePrice
plt.figure(figsize=(10, 6))
sns.scatterplot(data=Ds1, x='GrLivArea', y='SalePrice')
plt.title('GrLivArea vs SalePrice')
plt.xlabel('Above Ground Living Area (sq ft)')
plt.ylabel('Sale Price ($)')
plt.show()

# %%
# Scatter plot for OverallQual vs SalePrice
plt.figure(figsize=(10, 6))
sns.boxplot(data=Ds1, x='OverallQual', y='SalePrice')
plt.title('Overall Quality vs SalePrice')
plt.xlabel('Overall Quality Rating')
plt.ylabel('Sale Price ($)')
plt.show()
